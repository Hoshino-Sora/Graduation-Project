# %%
# !rm -f *.txt

# %%
# 运行这个块，强制删掉旧的训练日志和旧存档
# !rm -f *.log
# !rm -f *.txt
# !rm -f outputs/models/*.pth
print("案发现场清理完毕，准备全新发射！")
# Out:
# 案发现场清理完毕，准备全新发射！

# %%
# 使用 nohup 把它扔到服务器纯后台，这样你关掉浏览器网页也绝对不会断！
import os
os.system("nohup python run_loocv.py > cloud_run.log 2>&1 &")
print("飞船已升空！5090 正在纯后台疯狂流汗！你可以关掉浏览器去睡觉了！")
# Out:
# 飞船已升空！5090 正在纯后台疯狂流汗！你可以关掉浏览器去睡觉了！

# %%
# 每次运行这个块，就会打印出日志的最后 30 行！
# !tail -n 30 cloud_run.log
# Out:
# 正在挂载数据管道: chb20_13_X.npy
# 正在挂载数据管道: chb20_14_X.npy
# 正在挂载数据管道: chb20_15_X.npy
# 正在挂载数据管道: chb20_16_X.npy
# 正在挂载数据管道: chb20_17_X.npy
# 正在挂载数据管道: chb20_21_X.npy
# 正在挂载数据管道: chb20_22_X.npy
# 正在挂载数据管道: chb20_23_X.npy
# 正在挂载数据管道: chb20_25_X.npy
# 正在挂载数据管道: chb20_26_X.npy
# 正在挂载数据管道: chb20_27_X.npy
# 正在挂载数据管道: chb20_28_X.npy
# 正在挂载数据管道: chb20_29_X.npy
# 正在挂载数据管道: chb20_30_X.npy
# 正在挂载数据管道: chb20_31_X.npy
# 正在挂载数据管道: chb20_34_X.npy
# 正在挂载数据管道: chb20_59_X.npy
# 正在挂载数据管道: chb20_60_X.npy
# 正在挂载数据管道: chb20_68_X.npy
# 正在挂载数据管道: chb21_01_X.npy
# 正在挂载数据管道: chb21_02_X.npy
# 正在挂载数据管道: chb21_03_X.npy
# 正在挂载数据管道: chb21_04_X.npy
# 正在挂载数据管道: chb21_05_X.npy
# 正在挂载数据管道: chb21_06_X.npy
# 正在挂载数据管道: chb21_07_X.npy
# 正在挂载数据管道: chb21_08_X.npy
# 正在挂载数据管道: chb21_09_X.npy
# 正在挂载数据管道: chb21_10_X.npy
# 正在挂载数据管道: chb21_11_X.npy

# %%
# 1. 魔法指令执行终端命令，加上 > log 转移输出，加上 & 放入后台！
import os
os.system("nohup python run_eval_all.py > eval.log 2>&1 &")

print("后台推理已点火！让我康康你的模型正不正常啊？")
# Out:
# 后台推理已点火！让我康康你的模型正不正常啊？

# %%
# !pkill -9 -f run_loocv.py

# %%
tail -f cloud_run.log

# %%
tail -f eval.log
