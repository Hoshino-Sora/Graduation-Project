# %%
# 运行这个块，强制删掉旧的训练日志和旧存档
# !rm -f cloud_run.log
# !rm -f *.txt
# !rm -f outputs/models/*.pth
print("案发现场清理完毕，准备全新发射！")
# Out:
# 案发现场清理完毕，准备全新发射！

# %%
# 使用 nohup 把它扔到服务器纯后台，这样你关掉浏览器网页也绝对不会断！
import os
os.system("nohup python run_loocv.py > cloud_run.log 2>&1 &")
print("飞船已升空！5090 正在纯后台疯狂流汗！你可以关掉浏览器去睡觉了！")
# Out:
# 飞船已升空！5090 正在纯后台疯狂流汗！你可以关掉浏览器去睡觉了！

# %%
# 每次运行这个块，就会打印出日志的最后 30 行！
# !tail -n 30 cloud_run.log
# Out:
# 挂载成功！该病历共包含 2504 个切窗样本。
# 正在挂载数据管道: chb24_01_X.npy
# 挂载成功！该病历共包含 1800 个切窗样本。
# 正在挂载数据管道: chb24_03_X.npy
# 挂载成功！该病历共包含 1800 个切窗样本。
# 正在挂载数据管道: chb24_04_X.npy
# 挂载成功！该病历共包含 1800 个切窗样本。
# 正在挂载数据管道: chb24_06_X.npy
# 挂载成功！该病历共包含 1800 个切窗样本。
# 正在挂载数据管道: chb24_07_X.npy
# 挂载成功！该病历共包含 1800 个切窗样本。
# 正在挂载数据管道: chb24_09_X.npy
# 挂载成功！该病历共包含 1800 个切窗样本。
# 正在挂载数据管道: chb24_11_X.npy
# 挂载成功！该病历共包含 1800 个切窗样本。
# 正在挂载数据管道: chb24_13_X.npy
# 挂载成功！该病历共包含 1800 个切窗样本。
# 正在挂载数据管道: chb24_14_X.npy
# 挂载成功！该病历共包含 1800 个切窗样本。
# 正在挂载数据管道: chb24_15_X.npy
# 挂载成功！该病历共包含 1800 个切窗样本。
# 正在挂载数据管道: chb24_17_X.npy
# 挂载成功！该病历共包含 1800 个切窗样本。
# 正在挂载数据管道: chb24_21_X.npy
# 挂载成功！该病历共包含 1800 个切窗样本。
# 训练军团发货完毕！Train: 1333887 窗 | Val: 341216 窗。
#
#
# [全新启动] 断点续训未开启或无旧存档，无视干扰，开启全新训练流水线...

# %%
# 1. 魔法指令执行终端命令，加上 > log 转移输出，加上 & 放入后台！
import os
os.system("nohup python run_eval_all.py > eval_mixup.log 2>&1 &")

print("后台推理已点火！让我康康你的模型正不正常啊？")
# Out:
# 后台推理已点火！让我康康你的模型正不正常啊？
